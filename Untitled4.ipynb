# %% [markdown]
# <a href="https://colab.research.google.com/github/23495A0529/CASE123495A0529/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
mouna=pd.read_csv('energy.csv')
print(mouna)
srh=mouna[mouna['State']=='Andhra']
rcb=mouna[mouna['State']=='Karnataka']
fig1,diag1=plt.subplots(2)
diag1[0].plot(srh['Date'],srh['Consumption'])
diag1[1].plot(rcb['Date'],rcb['Consumption'],color='red')

#barc  chart telengana tripura
revanth=mouna[mouna['State']=='Telengana']
cm=mouna[mouna['State']=='Tripura']

fig,diag=plt.subplots(2)
diag[0].bar(revanth['Date'],revanth['Consumption'],color='red')
diag[1].bar(cm['Date'],cm['Consumption'],color='yellow')

State1='Delhi'
State2='Odisha'
State3='Up'
State4='Punjab'
cse5=[State1,State2]

cse4=mouna[mouna['State']==State1]['Consumption'].sum()
cse3=mouna[mouna['State']==State2]['Consumption'].sum()
cse2=[cse3,cse4]
fig,diag=plt.subplots(2)
diag[0].pie(cse2,labels=cse5,autopct='%1.1f%%')
cse5=[State1,State2]
cse4=mouna[mouna['State']==State1]['Consumption'].sum()
cse3=mouna[mouna['State']==State2]['Consumption'].sum()
cse2=[cse3,cse4]
diag[1].pie(cse2,labels=cse5,autopct='%1.1f%%')
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]
# ([<matplotlib.patches.Wedge at 0x7cdf956dec80>,
# ...
#  [Text(0.36382313614700484, 1.0380909043066306, 'Delhi'),
#   Text(-0.36382313614700473, -1.0380909043066306, 'Odisha')],
#  [Text(0.1984489833529117, 0.5662314023490712, '39.3%'),
#   Text(-0.19844898335291164, -0.5662314023490712, '60.7%')])
